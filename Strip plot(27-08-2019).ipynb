# %% [markdown]
# ### Strip plot
# A strip plot is a scatter plot where one of the variables is categorical.
# They can be combined with other plots to provide additional information.

# %% [markdown]
# This is a dataset that contains information about shot attempts made by professional basketball players.

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
plt.rcParams['figure.figsize'] = (20.0, 10.0)
plt.rcParams['font.family'] = "serif"

# %%
df = pd.read_csv('Desktop/Promize IT/shot_logs.csv',usecols=['player_name','SHOT_DIST','PTS_TYPE','SHOT_RESULT'])
players_to_use = ['kyrie irving', 'lebron james', 'stephen curry', 'jj redick']
df = df.loc[df.player_name.isin(players_to_use)]
df.head()
# Out:
#        SHOT_DIST  PTS_TYPE SHOT_RESULT    player_name
# 14054        8.0         2      missed  stephen curry
# 14055       25.9         3      missed  stephen curry
# 14056       23.8         3        made  stephen curry
# 14057       27.5         3        made  stephen curry
# 14058       29.3         3      missed  stephen curry

# %%
p = sns.stripplot(data=df, x='player_name', y='SHOT_DIST')#Basic plot

# %%
p = sns.stripplot(data=df,
                  x='player_name',
                  y='SHOT_DIST',
                  hue='SHOT_RESULT')# Change the color to represent whether the shot was made or missed

# %%
p = sns.stripplot(data=df,
                  x='player_name',
                  y='SHOT_DIST',
                  hue='SHOT_RESULT',
                  order=sorted(players_to_use))#Change the order in which the names are displayed

# %%
p = sns.stripplot(data=df,
                  x='player_name',
                  y='SHOT_DIST',
                  hue='SHOT_RESULT',
                  order=sorted(players_to_use),
                  jitter=0.25)#jitter can be used to randomly provide displacements along the horizontal,which is useful when there are large clusters of datapoints

# %%
p = sns.stripplot(data=df,
                  x='player_name',
                  y='SHOT_DIST',
                  hue='SHOT_RESULT',
                  order=sorted(players_to_use),
                  jitter=0.25,
                  dodge=True)#By using dodge we can split the data

# %%
p = sns.stripplot(data=df,
                  y='player_name',
                  x='SHOT_DIST',
                  hue='SHOT_RESULT',
                  order=sorted(players_to_use),
                  jitter=0.25,
                  dodge=False,
                  orient='h')#Flipping x and y inputs and setting orient to ‘h’ can be used to make a horizontal plot

# %%
p = sns.stripplot(data=df,
                  x='player_name',
                  y='SHOT_DIST',
                  hue='SHOT_RESULT',
                  order=sorted(players_to_use),
                  jitter=0.25,
                  dodge=True,
                  size=8)#Adjust the marker size

# %%
p = sns.stripplot(data=df,
                  x='player_name',
                  y='SHOT_DIST',
                  hue='SHOT_RESULT',
                  order=sorted(players_to_use),
                  jitter=0.25,
                  dodge=True,
                  size=8,
                  linewidth=3)#Adjust the linewidth of the edges of the circles

# %% [markdown]
# # Decision Trees:

# %% [markdown]
# ## Decision Tree comes under the Supervised Learning. It is used for Classification as well as Regression(CART).

# %%
from IPython.display import Image
Image(r"C:\Users\Veerabhadra\Documents\DS\Screenshots\DT1.jpg")

# %%
from IPython.display import Image
Image(r"C:\Users\Veerabhadra\Documents\DS\Screenshots\dt2.jpg")

# %%
from IPython.display import Image
Image(r"C:\Users\Veerabhadra\Documents\DS\Screenshots\dt3.jpg")

# %%
from IPython.display import Image
Image(r"C:\Users\Veerabhadra\Documents\DS\Screenshots\dt4.jpg")

# %% [markdown]
# ## When to stop further splitting??
# - When the output classification becomes same or
# - When there is a single record in the split

# %%
from IPython.display import Image
Image(r"C:\Users\Veerabhadra\Documents\DS\Screenshots\dt5.jpg")

# %%
from IPython.display import Image
Image(r"C:\Users\Veerabhadra\Documents\DS\Screenshots\dt19.jpg")

# %%
from IPython.display import Image
Image(r"C:\Users\Veerabhadra\Documents\DS\Screenshots\dt20.jpg")

# %%
from IPython.display import Image
Image(r"C:\Users\Veerabhadra\Documents\DS\Screenshots\dt6.jpg")

# %% [markdown]
# ## Classification Rules: The traversal of the root node to each any every leaf node is called as classification rule

# %%
from IPython.display import Image
Image(r"C:\Users\Veerabhadra\Documents\DS\Screenshots\dt7.jpg")

# %% [markdown]
# ## Taking Income as a root node

# %%
from IPython.display import Image
Image(r"C:\Users\Veerabhadra\Documents\DS\Screenshots\dt8.jpg")

# %%
from IPython.display import Image
Image(r"C:\Users\Veerabhadra\Documents\DS\Screenshots\dt9.jpg")

# %%
from IPython.display import Image
Image(r"C:\Users\Veerabhadra\Documents\DS\Screenshots\dt10.jpg")

# %%
from IPython.display import Image
Image(r"C:\Users\Veerabhadra\Documents\DS\Screenshots\dt11.jpg")

# %%
from IPython.display import Image
Image(r"C:\Users\Veerabhadra\Documents\DS\Screenshots\dt12.jpg")

# %%
from IPython.display import Image
Image(r"C:\Users\Veerabhadra\Documents\DS\Screenshots\dt13.jpg")

# %% [markdown]
# ## Decision Tree Algorithm works at the backend based on the method called as entropy

# %%
from IPython.display import Image
Image(r"C:\Users\Veerabhadra\Documents\DS\Screenshots\dt14.jpg")

# %% [markdown]
# # Creating a Perfect Decision Tree:

# %%
from IPython.display import Image
Image(r"C:\Users\Veerabhadra\Documents\DS\Screenshots\dt15.jpg")

# %%
from IPython.display import Image
Image(r"C:\Users\Veerabhadra\Documents\DS\Screenshots\dt16.jpg")

# %%
from IPython.display import Image
Image(r"C:\Users\Veerabhadra\Documents\DS\Screenshots\dt17.jpg")

# %%
from IPython.display import Image
Image(r"C:\Users\Veerabhadra\Documents\DS\Screenshots\dt18.jpg")
